# %%
DATA_DIR = "/home/user/.cache/gpt-sketchpad/data"

# %%
import os
import time
import datasets
import tiktoken
import numpy as np
from datasets import load_dataset

# %%
dataset_hf_path = "HuggingFaceFW/fineweb-edu"
dataset_hf_name = "sample-10BT"
dataset_hf_split = "train"
data_save_folder = os.path.join(DATA_DIR, "fineweb-edu-sample-10BT")

dataset_hf_names = datasets.get_dataset_config_names(dataset_hf_path)
print(f"Dataset configs: {dataset_hf_names[:5]}")
assert dataset_hf_name in dataset_hf_names

dataset_hf_splits = datasets.get_dataset_split_names(dataset_hf_path, dataset_hf_name)
print(f"Dataset splits: {dataset_hf_splits}")
assert dataset_hf_split in dataset_hf_splits
# Out:
# Resolving data files:   0%|          | 0/2410 [00:00<?, ?it/s]
# Dataset configs: ['default', 'sample-10BT', 'sample-100BT', 'sample-350BT', 'CC-MAIN-2025-05']
# Resolving data files:   0%|          | 0/2410 [00:00<?, ?it/s]
# Dataset splits: ['train']

# %%
os.makedirs(data_save_folder, exist_ok=True)

# %%
fw = load_dataset(
    dataset_hf_path,
    name=dataset_hf_name,
    split=dataset_hf_split,
    # streaming=True,
)
# Out:
# Resolving data files:   0%|          | 0/2410 [00:00<?, ?it/s]
# sample/10BT/000_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/001_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/002_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/003_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/004_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/005_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/006_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/007_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/008_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/009_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/010_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/011_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/012_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# sample/10BT/013_00000.parquet:   0%|          | 0.00/541M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9672101 [00:00<?, ? examples/s]
# Loading dataset shards:   0%|          | 0/98 [00:00<?, ?it/s]

# %%
tokenizer = tiktoken.get_encoding("gpt2")
eot = tokenizer._special_tokens['<|endoftext|>']

# %%
def save_buff(tokens_shard, shard_idx):
    tokens_np = np.array(tokens_shard, dtype=np.int32)
    assert (0 <= tokens_np).all() and (tokens_np < 2**16).all()
    tokens_np = tokens_np.astype(np.uint16)

    split = 'val' if shard_idx == 0 else 'train'
    data_filename = f"edufineweb_{split}_{shard_idx:06d}.npy"
    data_filepath = os.path.join(data_save_folder, data_filename)
    np.save(data_filepath, tokens_np)
    print(f"Saved {data_filepath} with shape {tokens_np.shape} and dtype {tokens_np.dtype}")

# %%
# iterate through the dataset
tokens_running_buff = []
shard_idx = 0
shard_size = 100_000_000
total_num_tokens = 0
total_expected_tokens = 10_000_000_000  # 10 billion tokens
time_start = time.time()
ts = time.time()
for i, item in enumerate(fw):
    # print(item.keys())
    text = item['text']
    tokens = [eot] + tokenizer.encode_ordinary(text)
    tokens_running_buff.extend(tokens)
    total_num_tokens += len(tokens)
    
    # Print Periodically
    tnow = time.time()
    dt = tnow - ts
    if dt > 15:
        ts = time.time()
        
        tok_per_sec = total_num_tokens / (tnow - time_start)
        remaining_tokens = total_expected_tokens - total_num_tokens
        print(f"Processed {total_num_tokens:,} / {total_expected_tokens:,} tokens so far, {tok_per_sec:,.0f} tok/sec, ETA: {remaining_tokens / tok_per_sec / 3600:.2f} hours")

    if len(tokens_running_buff) >= shard_size:
        # TODO: save here
        tokens_shard = tokens_running_buff[:shard_size]
        tokens_running_buff = tokens_running_buff[shard_size:]
        
        save_buff(tokens_shard, shard_idx)

        shard_idx += 1

    # if time.time() - time_start > 64:
    #     break
# Save any remaining tokens
if len(tokens_running_buff) > 0:
    save_buff(tokens_running_buff, shard_idx)
# Out:
# Processed 34,945,541 / 10,000,000,000 tokens so far, 2,329,667 tok/sec, ETA: 1.19 hours
# Processed 67,498,162 / 10,000,000,000 tokens so far, 2,249,907 tok/sec, ETA: 1.23 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_val_000000.npy with shape (100000000,) and dtype uint16
# Processed 100,003,591 / 10,000,000,000 tokens so far, 1,888,544 tok/sec, ETA: 1.46 hours
# Processed 133,949,951 / 10,000,000,000 tokens so far, 1,971,220 tok/sec, ETA: 1.39 hours
# Processed 167,995,258 / 10,000,000,000 tokens so far, 2,025,187 tok/sec, ETA: 1.35 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000001.npy with shape (100000000,) and dtype uint16
# Processed 200,000,746 / 10,000,000,000 tokens so far, 1,942,744 tok/sec, ETA: 1.40 hours
# Processed 235,371,321 / 10,000,000,000 tokens so far, 1,995,558 tok/sec, ETA: 1.36 hours
# Processed 270,688,704 / 10,000,000,000 tokens so far, 2,036,048 tok/sec, ETA: 1.33 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000002.npy with shape (100000000,) and dtype uint16
# Processed 300,000,546 / 10,000,000,000 tokens so far, 1,947,234 tok/sec, ETA: 1.38 hours
# Processed 335,195,091 / 10,000,000,000 tokens so far, 1,982,641 tok/sec, ETA: 1.35 hours
# Processed 370,577,552 / 10,000,000,000 tokens so far, 2,013,297 tok/sec, ETA: 1.33 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000003.npy with shape (100000000,) and dtype uint16
# Processed 400,001,258 / 10,000,000,000 tokens so far, 1,956,032 tok/sec, ETA: 1.36 hours
# Processed 432,216,004 / 10,000,000,000 tokens so far, 1,969,124 tok/sec, ETA: 1.35 hours
# Processed 467,353,757 / 10,000,000,000 tokens so far, 1,993,009 tok/sec, ETA: 1.33 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000004.npy with shape (100000000,) and dtype uint16
# Processed 500,002,083 / 10,000,000,000 tokens so far, 1,947,387 tok/sec, ETA: 1.36 hours
# Processed 534,635,732 / 10,000,000,000 tokens so far, 1,967,341 tok/sec, ETA: 1.34 hours
# Processed 570,113,191 / 10,000,000,000 tokens so far, 1,988,150 tok/sec, ETA: 1.32 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000005.npy with shape (100000000,) and dtype uint16
# Processed 600,002,552 / 10,000,000,000 tokens so far, 1,952,600 tok/sec, ETA: 1.34 hours
# Processed 635,368,893 / 10,000,000,000 tokens so far, 1,971,449 tok/sec, ETA: 1.32 hours
# Processed 670,434,990 / 10,000,000,000 tokens so far, 1,987,738 tok/sec, ETA: 1.30 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000006.npy with shape (100000000,) and dtype uint16
# Processed 700,003,601 / 10,000,000,000 tokens so far, 1,962,923 tok/sec, ETA: 1.32 hours
# Processed 735,263,502 / 10,000,000,000 tokens so far, 1,978,571 tok/sec, ETA: 1.30 hours
# Processed 770,478,631 / 10,000,000,000 tokens so far, 1,992,891 tok/sec, ETA: 1.29 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000007.npy with shape (100000000,) and dtype uint16
# Processed 800,000,953 / 10,000,000,000 tokens so far, 1,975,205 tok/sec, ETA: 1.29 hours
# Processed 834,773,260 / 10,000,000,000 tokens so far, 1,987,451 tok/sec, ETA: 1.28 hours
# Processed 869,540,146 / 10,000,000,000 tokens so far, 1,998,841 tok/sec, ETA: 1.27 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000008.npy with shape (100000000,) and dtype uint16
# Processed 900,002,566 / 10,000,000,000 tokens so far, 1,970,497 tok/sec, ETA: 1.28 hours
# Processed 934,848,763 / 10,000,000,000 tokens so far, 1,981,705 tok/sec, ETA: 1.27 hours
# Processed 969,314,099 / 10,000,000,000 tokens so far, 1,991,441 tok/sec, ETA: 1.26 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000009.npy with shape (100000000,) and dtype uint16
# Processed 1,000,001,042 / 10,000,000,000 tokens so far, 1,968,377 tok/sec, ETA: 1.27 hours
# Processed 1,034,767,641 / 10,000,000,000 tokens so far, 1,978,396 tok/sec, ETA: 1.26 hours
# Processed 1,069,233,906 / 10,000,000,000 tokens so far, 1,987,298 tok/sec, ETA: 1.25 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000010.npy with shape (100000000,) and dtype uint16
# Processed 1,100,000,828 / 10,000,000,000 tokens so far, 1,965,224 tok/sec, ETA: 1.26 hours
# Processed 1,135,078,492 / 10,000,000,000 tokens so far, 1,974,965 tok/sec, ETA: 1.25 hours
# Processed 1,169,390,349 / 10,000,000,000 tokens so far, 1,982,912 tok/sec, ETA: 1.24 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000011.npy with shape (100000000,) and dtype uint16
# Processed 1,200,003,629 / 10,000,000,000 tokens so far, 1,964,359 tok/sec, ETA: 1.24 hours
# Processed 1,234,600,824 / 10,000,000,000 tokens so far, 1,972,558 tok/sec, ETA: 1.23 hours
# Processed 1,269,718,688 / 10,000,000,000 tokens so far, 1,981,185 tok/sec, ETA: 1.22 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000012.npy with shape (100000000,) and dtype uint16
# Processed 1,300,005,484 / 10,000,000,000 tokens so far, 1,962,380 tok/sec, ETA: 1.23 hours
# Processed 1,334,868,154 / 10,000,000,000 tokens so far, 1,970,389 tok/sec, ETA: 1.22 hours
# Processed 1,369,712,400 / 10,000,000,000 tokens so far, 1,978,014 tok/sec, ETA: 1.21 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000013.npy with shape (100000000,) and dtype uint16
# Processed 1,400,008,186 / 10,000,000,000 tokens so far, 1,964,222 tok/sec, ETA: 1.22 hours
# Processed 1,434,779,731 / 10,000,000,000 tokens so far, 1,971,513 tok/sec, ETA: 1.21 hours
# Processed 1,469,749,334 / 10,000,000,000 tokens so far, 1,978,778 tok/sec, ETA: 1.20 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000014.npy with shape (100000000,) and dtype uint16
# Processed 1,500,005,925 / 10,000,000,000 tokens so far, 1,963,875 tok/sec, ETA: 1.20 hours
# Processed 1,535,221,357 / 10,000,000,000 tokens so far, 1,971,266 tok/sec, ETA: 1.19 hours
# Processed 1,570,041,184 / 10,000,000,000 tokens so far, 1,977,880 tok/sec, ETA: 1.18 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000015.npy with shape (100000000,) and dtype uint16
# Processed 1,600,000,739 / 10,000,000,000 tokens so far, 1,963,972 tok/sec, ETA: 1.19 hours
# Processed 1,634,775,930 / 10,000,000,000 tokens so far, 1,970,378 tok/sec, ETA: 1.18 hours
# Processed 1,669,149,963 / 10,000,000,000 tokens so far, 1,976,080 tok/sec, ETA: 1.17 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000016.npy with shape (100000000,) and dtype uint16
# Processed 1,700,001,932 / 10,000,000,000 tokens so far, 1,960,012 tok/sec, ETA: 1.18 hours
# Processed 1,734,714,481 / 10,000,000,000 tokens so far, 1,966,032 tok/sec, ETA: 1.17 hours
# Processed 1,769,462,434 / 10,000,000,000 tokens so far, 1,971,890 tok/sec, ETA: 1.16 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000017.npy with shape (100000000,) and dtype uint16
# Processed 1,800,000,696 / 10,000,000,000 tokens so far, 1,959,743 tok/sec, ETA: 1.16 hours
# Processed 1,834,857,423 / 10,000,000,000 tokens so far, 1,965,592 tok/sec, ETA: 1.15 hours
# Processed 1,869,352,635 / 10,000,000,000 tokens so far, 1,970,875 tok/sec, ETA: 1.15 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000018.npy with shape (100000000,) and dtype uint16
# Processed 1,900,004,025 / 10,000,000,000 tokens so far, 1,958,602 tok/sec, ETA: 1.15 hours
# Processed 1,934,820,474 / 10,000,000,000 tokens so far, 1,964,121 tok/sec, ETA: 1.14 hours
# Processed 1,968,976,786 / 10,000,000,000 tokens so far, 1,968,815 tok/sec, ETA: 1.13 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000019.npy with shape (100000000,) and dtype uint16
# Processed 2,000,002,809 / 10,000,000,000 tokens so far, 1,957,943 tok/sec, ETA: 1.13 hours
# Processed 2,034,755,648 / 10,000,000,000 tokens so far, 1,963,136 tok/sec, ETA: 1.13 hours
# Processed 2,069,309,439 / 10,000,000,000 tokens so far, 1,967,984 tok/sec, ETA: 1.12 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000020.npy with shape (100000000,) and dtype uint16
# Processed 2,100,000,874 / 10,000,000,000 tokens so far, 1,955,179 tok/sec, ETA: 1.12 hours
# Processed 2,135,116,320 / 10,000,000,000 tokens so far, 1,960,493 tok/sec, ETA: 1.11 hours
# Processed 2,169,492,718 / 10,000,000,000 tokens so far, 1,964,993 tok/sec, ETA: 1.11 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000021.npy with shape (100000000,) and dtype uint16
# Processed 2,200,004,214 / 10,000,000,000 tokens so far, 1,950,850 tok/sec, ETA: 1.11 hours
# Processed 2,234,555,451 / 10,000,000,000 tokens so far, 1,955,459 tok/sec, ETA: 1.10 hours
# Processed 2,268,706,439 / 10,000,000,000 tokens so far, 1,959,621 tok/sec, ETA: 1.10 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000022.npy with shape (100000000,) and dtype uint16
# Processed 2,300,000,667 / 10,000,000,000 tokens so far, 1,947,944 tok/sec, ETA: 1.10 hours
# Processed 2,334,357,506 / 10,000,000,000 tokens so far, 1,952,241 tok/sec, ETA: 1.09 hours
# Processed 2,368,720,882 / 10,000,000,000 tokens so far, 1,956,436 tok/sec, ETA: 1.08 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000023.npy with shape (100000000,) and dtype uint16
# Processed 2,400,008,288 / 10,000,000,000 tokens so far, 1,947,647 tok/sec, ETA: 1.08 hours
# Processed 2,434,855,862 / 10,000,000,000 tokens so far, 1,952,163 tok/sec, ETA: 1.08 hours
# Processed 2,469,183,261 / 10,000,000,000 tokens so far, 1,956,159 tok/sec, ETA: 1.07 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000024.npy with shape (100000000,) and dtype uint16
# Processed 2,500,007,574 / 10,000,000,000 tokens so far, 1,945,637 tok/sec, ETA: 1.07 hours
# Processed 2,534,553,415 / 10,000,000,000 tokens so far, 1,949,759 tok/sec, ETA: 1.06 hours
# Processed 2,568,818,276 / 10,000,000,000 tokens so far, 1,953,576 tok/sec, ETA: 1.06 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000025.npy with shape (100000000,) and dtype uint16
# Processed 2,600,006,688 / 10,000,000,000 tokens so far, 1,945,415 tok/sec, ETA: 1.06 hours
# Processed 2,634,650,350 / 10,000,000,000 tokens so far, 1,949,456 tok/sec, ETA: 1.05 hours
# Processed 2,669,203,089 / 10,000,000,000 tokens so far, 1,953,342 tok/sec, ETA: 1.04 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000026.npy with shape (100000000,) and dtype uint16
# Processed 2,700,001,226 / 10,000,000,000 tokens so far, 1,941,353 tok/sec, ETA: 1.04 hours
# Processed 2,734,355,337 / 10,000,000,000 tokens so far, 1,945,075 tok/sec, ETA: 1.04 hours
# Processed 2,768,959,358 / 10,000,000,000 tokens so far, 1,948,896 tok/sec, ETA: 1.03 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000027.npy with shape (100000000,) and dtype uint16
# Processed 2,800,000,949 / 10,000,000,000 tokens so far, 1,939,087 tok/sec, ETA: 1.03 hours
# Processed 2,834,938,124 / 10,000,000,000 tokens so far, 1,943,097 tok/sec, ETA: 1.02 hours
# Processed 2,869,543,099 / 10,000,000,000 tokens so far, 1,946,799 tok/sec, ETA: 1.02 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000028.npy with shape (100000000,) and dtype uint16
# Processed 2,900,001,112 / 10,000,000,000 tokens so far, 1,934,599 tok/sec, ETA: 1.02 hours
# Processed 2,934,448,289 / 10,000,000,000 tokens so far, 1,938,184 tok/sec, ETA: 1.01 hours
# Processed 2,969,020,295 / 10,000,000,000 tokens so far, 1,941,780 tok/sec, ETA: 1.01 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000029.npy with shape (100000000,) and dtype uint16
# Processed 3,000,006,229 / 10,000,000,000 tokens so far, 1,931,770 tok/sec, ETA: 1.01 hours
# Processed 3,034,561,085 / 10,000,000,000 tokens so far, 1,935,328 tok/sec, ETA: 1.00 hours
# Processed 3,068,854,004 / 10,000,000,000 tokens so far, 1,938,652 tok/sec, ETA: 0.99 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000030.npy with shape (100000000,) and dtype uint16
# Processed 3,100,000,758 / 10,000,000,000 tokens so far, 1,927,473 tok/sec, ETA: 0.99 hours
# Processed 3,133,828,891 / 10,000,000,000 tokens so far, 1,930,497 tok/sec, ETA: 0.99 hours
# Processed 3,168,273,372 / 10,000,000,000 tokens so far, 1,933,845 tok/sec, ETA: 0.98 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000031.npy with shape (100000000,) and dtype uint16
# Processed 3,200,033,387 / 10,000,000,000 tokens so far, 1,927,187 tok/sec, ETA: 0.98 hours
# Processed 3,234,530,322 / 10,000,000,000 tokens so far, 1,930,522 tok/sec, ETA: 0.97 hours
# Processed 3,269,167,663 / 10,000,000,000 tokens so far, 1,933,880 tok/sec, ETA: 0.97 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000032.npy with shape (100000000,) and dtype uint16
# Processed 3,300,000,339 / 10,000,000,000 tokens so far, 1,926,238 tok/sec, ETA: 0.97 hours
# Processed 3,334,075,790 / 10,000,000,000 tokens so far, 1,929,236 tok/sec, ETA: 0.96 hours
# Processed 3,368,300,192 / 10,000,000,000 tokens so far, 1,932,268 tok/sec, ETA: 0.95 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000033.npy with shape (100000000,) and dtype uint16
# Processed 3,400,001,125 / 10,000,000,000 tokens so far, 1,922,846 tok/sec, ETA: 0.95 hours
# Processed 3,434,032,744 / 10,000,000,000 tokens so far, 1,925,755 tok/sec, ETA: 0.95 hours
# Processed 3,468,889,488 / 10,000,000,000 tokens so far, 1,929,075 tok/sec, ETA: 0.94 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000034.npy with shape (100000000,) and dtype uint16
# Processed 3,500,000,722 / 10,000,000,000 tokens so far, 1,921,525 tok/sec, ETA: 0.94 hours
# Processed 3,534,852,071 / 10,000,000,000 tokens so far, 1,924,807 tok/sec, ETA: 0.93 hours
# Processed 3,569,645,231 / 10,000,000,000 tokens so far, 1,928,004 tok/sec, ETA: 0.93 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000035.npy with shape (100000000,) and dtype uint16
# Processed 3,600,006,663 / 10,000,000,000 tokens so far, 1,919,052 tok/sec, ETA: 0.93 hours
# Processed 3,634,584,028 / 10,000,000,000 tokens so far, 1,922,113 tok/sec, ETA: 0.92 hours
# Processed 3,669,233,490 / 10,000,000,000 tokens so far, 1,925,165 tok/sec, ETA: 0.91 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000036.npy with shape (100000000,) and dtype uint16
# Processed 3,700,000,598 / 10,000,000,000 tokens so far, 1,917,626 tok/sec, ETA: 0.91 hours
# Processed 3,734,555,377 / 10,000,000,000 tokens so far, 1,920,603 tok/sec, ETA: 0.91 hours
# Processed 3,769,102,926 / 10,000,000,000 tokens so far, 1,923,532 tok/sec, ETA: 0.90 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000037.npy with shape (100000000,) and dtype uint16
# Processed 3,800,000,917 / 10,000,000,000 tokens so far, 1,915,447 tok/sec, ETA: 0.90 hours
# Processed 3,834,516,998 / 10,000,000,000 tokens so far, 1,918,341 tok/sec, ETA: 0.89 hours
# Processed 3,869,028,856 / 10,000,000,000 tokens so far, 1,921,189 tok/sec, ETA: 0.89 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000038.npy with shape (100000000,) and dtype uint16
# Processed 3,900,002,425 / 10,000,000,000 tokens so far, 1,914,324 tok/sec, ETA: 0.89 hours
# Processed 3,933,446,736 / 10,000,000,000 tokens so far, 1,916,628 tok/sec, ETA: 0.88 hours
# Processed 3,967,160,437 / 10,000,000,000 tokens so far, 1,919,029 tok/sec, ETA: 0.87 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000039.npy with shape (100000000,) and dtype uint16
# Processed 4,000,000,388 / 10,000,000,000 tokens so far, 1,911,523 tok/sec, ETA: 0.87 hours
# Processed 4,034,616,313 / 10,000,000,000 tokens so far, 1,914,343 tok/sec, ETA: 0.87 hours
# Processed 4,069,315,626 / 10,000,000,000 tokens so far, 1,917,162 tok/sec, ETA: 0.86 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000040.npy with shape (100000000,) and dtype uint16
# Processed 4,100,001,420 / 10,000,000,000 tokens so far, 1,910,722 tok/sec, ETA: 0.86 hours
# Processed 4,134,941,929 / 10,000,000,000 tokens so far, 1,913,628 tok/sec, ETA: 0.85 hours
# Processed 4,169,671,534 / 10,000,000,000 tokens so far, 1,916,395 tok/sec, ETA: 0.85 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000041.npy with shape (100000000,) and dtype uint16
# Processed 4,200,017,532 / 10,000,000,000 tokens so far, 1,909,782 tok/sec, ETA: 0.84 hours
# Processed 4,234,819,225 / 10,000,000,000 tokens so far, 1,912,561 tok/sec, ETA: 0.84 hours
# Processed 4,269,466,598 / 10,000,000,000 tokens so far, 1,915,233 tok/sec, ETA: 0.83 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000042.npy with shape (100000000,) and dtype uint16
# Processed 4,300,000,773 / 10,000,000,000 tokens so far, 1,908,936 tok/sec, ETA: 0.83 hours
# Processed 4,335,022,535 / 10,000,000,000 tokens so far, 1,911,753 tok/sec, ETA: 0.82 hours
# Processed 4,369,641,022 / 10,000,000,000 tokens so far, 1,914,356 tok/sec, ETA: 0.82 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000043.npy with shape (100000000,) and dtype uint16
# Processed 4,400,000,277 / 10,000,000,000 tokens so far, 1,907,666 tok/sec, ETA: 0.82 hours
# Processed 4,434,387,116 / 10,000,000,000 tokens so far, 1,910,151 tok/sec, ETA: 0.81 hours
# Processed 4,468,642,643 / 10,000,000,000 tokens so far, 1,912,549 tok/sec, ETA: 0.80 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000044.npy with shape (100000000,) and dtype uint16
# Processed 4,500,000,879 / 10,000,000,000 tokens so far, 1,906,538 tok/sec, ETA: 0.80 hours
# Processed 4,534,795,890 / 10,000,000,000 tokens so far, 1,909,147 tok/sec, ETA: 0.80 hours
# Processed 4,569,342,610 / 10,000,000,000 tokens so far, 1,911,619 tok/sec, ETA: 0.79 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000045.npy with shape (100000000,) and dtype uint16
# Processed 4,600,001,012 / 10,000,000,000 tokens so far, 1,906,162 tok/sec, ETA: 0.79 hours
# Processed 4,634,678,063 / 10,000,000,000 tokens so far, 1,908,668 tok/sec, ETA: 0.78 hours
# Processed 4,669,069,324 / 10,000,000,000 tokens so far, 1,911,026 tok/sec, ETA: 0.77 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000046.npy with shape (100000000,) and dtype uint16
# Processed 4,700,009,232 / 10,000,000,000 tokens so far, 1,905,335 tok/sec, ETA: 0.77 hours
# Processed 4,734,912,866 / 10,000,000,000 tokens so far, 1,907,883 tok/sec, ETA: 0.77 hours
# Processed 4,769,604,241 / 10,000,000,000 tokens so far, 1,910,315 tok/sec, ETA: 0.76 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000047.npy with shape (100000000,) and dtype uint16
# Processed 4,800,005,566 / 10,000,000,000 tokens so far, 1,904,880 tok/sec, ETA: 0.76 hours
# Processed 4,834,978,293 / 10,000,000,000 tokens so far, 1,907,404 tok/sec, ETA: 0.75 hours
# Processed 4,869,875,095 / 10,000,000,000 tokens so far, 1,909,869 tok/sec, ETA: 0.75 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000048.npy with shape (100000000,) and dtype uint16
# Processed 4,900,004,157 / 10,000,000,000 tokens so far, 1,905,104 tok/sec, ETA: 0.74 hours
# Processed 4,935,470,475 / 10,000,000,000 tokens so far, 1,907,767 tok/sec, ETA: 0.74 hours
# Processed 4,970,580,578 / 10,000,000,000 tokens so far, 1,910,263 tok/sec, ETA: 0.73 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000049.npy with shape (100000000,) and dtype uint16
# Processed 5,000,003,727 / 10,000,000,000 tokens so far, 1,905,721 tok/sec, ETA: 0.73 hours
# Processed 5,035,012,941 / 10,000,000,000 tokens so far, 1,908,155 tok/sec, ETA: 0.72 hours
# Processed 5,069,479,377 / 10,000,000,000 tokens so far, 1,910,357 tok/sec, ETA: 0.72 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000050.npy with shape (100000000,) and dtype uint16
# Processed 5,100,000,402 / 10,000,000,000 tokens so far, 1,905,763 tok/sec, ETA: 0.71 hours
# Processed 5,135,185,350 / 10,000,000,000 tokens so far, 1,908,215 tok/sec, ETA: 0.71 hours
# Processed 5,170,242,801 / 10,000,000,000 tokens so far, 1,910,593 tok/sec, ETA: 0.70 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000051.npy with shape (100000000,) and dtype uint16
# Processed 5,200,001,237 / 10,000,000,000 tokens so far, 1,905,991 tok/sec, ETA: 0.70 hours
# Processed 5,234,327,911 / 10,000,000,000 tokens so far, 1,908,082 tok/sec, ETA: 0.69 hours
# Processed 5,268,867,579 / 10,000,000,000 tokens so far, 1,910,227 tok/sec, ETA: 0.69 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000052.npy with shape (100000000,) and dtype uint16
# Processed 5,300,002,777 / 10,000,000,000 tokens so far, 1,905,342 tok/sec, ETA: 0.69 hours
# Processed 5,334,618,000 / 10,000,000,000 tokens so far, 1,907,500 tok/sec, ETA: 0.68 hours
# Processed 5,369,027,729 / 10,000,000,000 tokens so far, 1,909,561 tok/sec, ETA: 0.67 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000053.npy with shape (100000000,) and dtype uint16
# Processed 5,400,015,605 / 10,000,000,000 tokens so far, 1,904,961 tok/sec, ETA: 0.67 hours
# Processed 5,435,019,833 / 10,000,000,000 tokens so far, 1,907,218 tok/sec, ETA: 0.66 hours
# Processed 5,469,517,966 / 10,000,000,000 tokens so far, 1,909,273 tok/sec, ETA: 0.66 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000054.npy with shape (100000000,) and dtype uint16
# Processed 5,500,002,100 / 10,000,000,000 tokens so far, 1,904,375 tok/sec, ETA: 0.66 hours
# Processed 5,535,072,225 / 10,000,000,000 tokens so far, 1,906,615 tok/sec, ETA: 0.65 hours
# Processed 5,569,456,503 / 10,000,000,000 tokens so far, 1,908,596 tok/sec, ETA: 0.64 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000055.npy with shape (100000000,) and dtype uint16
# Processed 5,600,002,092 / 10,000,000,000 tokens so far, 1,904,387 tok/sec, ETA: 0.64 hours
# Processed 5,635,016,360 / 10,000,000,000 tokens so far, 1,906,567 tok/sec, ETA: 0.64 hours
# Processed 5,669,821,113 / 10,000,000,000 tokens so far, 1,908,657 tok/sec, ETA: 0.63 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000056.npy with shape (100000000,) and dtype uint16
# Processed 5,700,000,463 / 10,000,000,000 tokens so far, 1,904,395 tok/sec, ETA: 0.63 hours
# Processed 5,735,041,687 / 10,000,000,000 tokens so far, 1,906,547 tok/sec, ETA: 0.62 hours
# Processed 5,769,955,235 / 10,000,000,000 tokens so far, 1,908,636 tok/sec, ETA: 0.62 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000057.npy with shape (100000000,) and dtype uint16
# Processed 5,800,002,607 / 10,000,000,000 tokens so far, 1,905,396 tok/sec, ETA: 0.61 hours
# Processed 5,834,955,609 / 10,000,000,000 tokens so far, 1,907,479 tok/sec, ETA: 0.61 hours
# Processed 5,870,037,532 / 10,000,000,000 tokens so far, 1,909,584 tok/sec, ETA: 0.60 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000058.npy with shape (100000000,) and dtype uint16
# Processed 5,900,000,992 / 10,000,000,000 tokens so far, 1,905,618 tok/sec, ETA: 0.60 hours
# Processed 5,935,043,578 / 10,000,000,000 tokens so far, 1,907,693 tok/sec, ETA: 0.59 hours
# Processed 5,969,630,240 / 10,000,000,000 tokens so far, 1,909,603 tok/sec, ETA: 0.59 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000059.npy with shape (100000000,) and dtype uint16
# Processed 6,000,011,305 / 10,000,000,000 tokens so far, 1,905,790 tok/sec, ETA: 0.58 hours
# Processed 6,035,101,885 / 10,000,000,000 tokens so far, 1,907,845 tok/sec, ETA: 0.58 hours
# Processed 6,070,196,469 / 10,000,000,000 tokens so far, 1,909,882 tok/sec, ETA: 0.57 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000060.npy with shape (100000000,) and dtype uint16
# Processed 6,100,000,614 / 10,000,000,000 tokens so far, 1,906,214 tok/sec, ETA: 0.57 hours
# Processed 6,135,151,430 / 10,000,000,000 tokens so far, 1,908,254 tok/sec, ETA: 0.56 hours
# Processed 6,170,233,783 / 10,000,000,000 tokens so far, 1,910,252 tok/sec, ETA: 0.56 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000061.npy with shape (100000000,) and dtype uint16
# Processed 6,200,002,034 / 10,000,000,000 tokens so far, 1,906,536 tok/sec, ETA: 0.55 hours
# Processed 6,235,143,303 / 10,000,000,000 tokens so far, 1,908,535 tok/sec, ETA: 0.55 hours
# Processed 6,270,040,414 / 10,000,000,000 tokens so far, 1,910,445 tok/sec, ETA: 0.54 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000062.npy with shape (100000000,) and dtype uint16
# Processed 6,300,001,302 / 10,000,000,000 tokens so far, 1,906,426 tok/sec, ETA: 0.54 hours
# Processed 6,335,105,940 / 10,000,000,000 tokens so far, 1,908,386 tok/sec, ETA: 0.53 hours
# Processed 6,369,382,155 / 10,000,000,000 tokens so far, 1,910,081 tok/sec, ETA: 0.53 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000063.npy with shape (100000000,) and dtype uint16
# Processed 6,400,000,359 / 10,000,000,000 tokens so far, 1,906,073 tok/sec, ETA: 0.52 hours
# Processed 6,435,007,941 / 10,000,000,000 tokens so far, 1,907,975 tok/sec, ETA: 0.52 hours
# Processed 6,469,870,462 / 10,000,000,000 tokens so far, 1,909,818 tok/sec, ETA: 0.51 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000064.npy with shape (100000000,) and dtype uint16
# Processed 6,500,001,134 / 10,000,000,000 tokens so far, 1,905,810 tok/sec, ETA: 0.51 hours
# Processed 6,535,202,996 / 10,000,000,000 tokens so far, 1,907,740 tok/sec, ETA: 0.50 hours
# Processed 6,569,856,376 / 10,000,000,000 tokens so far, 1,909,494 tok/sec, ETA: 0.50 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000065.npy with shape (100000000,) and dtype uint16
# Processed 6,600,003,886 / 10,000,000,000 tokens so far, 1,905,972 tok/sec, ETA: 0.50 hours
# Processed 6,634,896,015 / 10,000,000,000 tokens so far, 1,907,784 tok/sec, ETA: 0.49 hours
# Processed 6,669,906,090 / 10,000,000,000 tokens so far, 1,909,613 tok/sec, ETA: 0.48 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000066.npy with shape (100000000,) and dtype uint16
# Processed 6,700,001,161 / 10,000,000,000 tokens so far, 1,905,997 tok/sec, ETA: 0.48 hours
# Processed 6,735,528,747 / 10,000,000,000 tokens so far, 1,907,962 tok/sec, ETA: 0.48 hours
# Processed 6,770,648,169 / 10,000,000,000 tokens so far, 1,909,795 tok/sec, ETA: 0.47 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000067.npy with shape (100000000,) and dtype uint16
# Processed 6,800,000,531 / 10,000,000,000 tokens so far, 1,906,561 tok/sec, ETA: 0.47 hours
# Processed 6,835,282,759 / 10,000,000,000 tokens so far, 1,908,426 tok/sec, ETA: 0.46 hours
# Processed 6,870,513,416 / 10,000,000,000 tokens so far, 1,910,262 tok/sec, ETA: 0.46 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000068.npy with shape (100000000,) and dtype uint16
# Processed 6,900,007,591 / 10,000,000,000 tokens so far, 1,906,927 tok/sec, ETA: 0.45 hours
# Processed 6,935,352,633 / 10,000,000,000 tokens so far, 1,908,782 tok/sec, ETA: 0.45 hours
# Processed 6,970,605,512 / 10,000,000,000 tokens so far, 1,910,597 tok/sec, ETA: 0.44 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000069.npy with shape (100000000,) and dtype uint16
# Processed 7,000,000,915 / 10,000,000,000 tokens so far, 1,907,079 tok/sec, ETA: 0.44 hours
# Processed 7,035,214,311 / 10,000,000,000 tokens so far, 1,908,871 tok/sec, ETA: 0.43 hours
# Processed 7,070,005,055 / 10,000,000,000 tokens so far, 1,910,535 tok/sec, ETA: 0.43 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000070.npy with shape (100000000,) and dtype uint16
# Processed 7,100,022,950 / 10,000,000,000 tokens so far, 1,908,446 tok/sec, ETA: 0.42 hours
# Processed 7,135,654,488 / 10,000,000,000 tokens so far, 1,910,321 tok/sec, ETA: 0.42 hours
# Processed 7,170,897,428 / 10,000,000,000 tokens so far, 1,912,077 tok/sec, ETA: 0.41 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000071.npy with shape (100000000,) and dtype uint16
# Processed 7,200,004,390 / 10,000,000,000 tokens so far, 1,909,096 tok/sec, ETA: 0.41 hours
# Processed 7,234,798,518 / 10,000,000,000 tokens so far, 1,910,722 tok/sec, ETA: 0.40 hours
# Processed 7,269,426,401 / 10,000,000,000 tokens so far, 1,912,291 tok/sec, ETA: 0.40 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000072.npy with shape (100000000,) and dtype uint16
# Processed 7,300,002,805 / 10,000,000,000 tokens so far, 1,908,937 tok/sec, ETA: 0.39 hours
# Processed 7,335,285,344 / 10,000,000,000 tokens so far, 1,910,669 tok/sec, ETA: 0.39 hours
# Processed 7,370,422,872 / 10,000,000,000 tokens so far, 1,912,349 tok/sec, ETA: 0.38 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000073.npy with shape (100000000,) and dtype uint16
# Processed 7,400,001,055 / 10,000,000,000 tokens so far, 1,909,253 tok/sec, ETA: 0.38 hours
# Processed 7,434,689,934 / 10,000,000,000 tokens so far, 1,910,808 tok/sec, ETA: 0.37 hours
# Processed 7,469,253,619 / 10,000,000,000 tokens so far, 1,912,319 tok/sec, ETA: 0.37 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000074.npy with shape (100000000,) and dtype uint16
# Processed 7,500,001,236 / 10,000,000,000 tokens so far, 1,909,074 tok/sec, ETA: 0.36 hours
# Processed 7,534,683,293 / 10,000,000,000 tokens so far, 1,910,607 tok/sec, ETA: 0.36 hours
# Processed 7,569,212,747 / 10,000,000,000 tokens so far, 1,912,090 tok/sec, ETA: 0.35 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000075.npy with shape (100000000,) and dtype uint16
# Processed 7,600,004,108 / 10,000,000,000 tokens so far, 1,908,685 tok/sec, ETA: 0.35 hours
# Processed 7,630,545,597 / 10,000,000,000 tokens so far, 1,909,163 tok/sec, ETA: 0.34 hours
# Processed 7,662,636,663 / 10,000,000,000 tokens so far, 1,910,024 tok/sec, ETA: 0.34 hours
# Processed 7,696,057,334 / 10,000,000,000 tokens so far, 1,911,209 tok/sec, ETA: 0.33 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000076.npy with shape (100000000,) and dtype uint16
# Processed 7,708,284,895 / 10,000,000,000 tokens so far, 1,907,141 tok/sec, ETA: 0.33 hours
# Processed 7,739,223,415 / 10,000,000,000 tokens so far, 1,907,715 tok/sec, ETA: 0.33 hours
# Processed 7,769,757,987 / 10,000,000,000 tokens so far, 1,908,186 tok/sec, ETA: 0.32 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000077.npy with shape (100000000,) and dtype uint16
# Processed 7,800,001,772 / 10,000,000,000 tokens so far, 1,904,712 tok/sec, ETA: 0.32 hours
# Processed 7,833,428,342 / 10,000,000,000 tokens so far, 1,905,893 tok/sec, ETA: 0.32 hours
# Processed 7,867,499,664 / 10,000,000,000 tokens so far, 1,907,212 tok/sec, ETA: 0.31 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000078.npy with shape (100000000,) and dtype uint16
# Processed 7,900,048,522 / 10,000,000,000 tokens so far, 1,903,703 tok/sec, ETA: 0.31 hours
# Processed 7,932,691,922 / 10,000,000,000 tokens so far, 1,904,684 tok/sec, ETA: 0.30 hours
# Processed 7,966,633,323 / 10,000,000,000 tokens so far, 1,905,969 tok/sec, ETA: 0.30 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000079.npy with shape (100000000,) and dtype uint16
# Processed 8,000,000,474 / 10,000,000,000 tokens so far, 1,902,830 tok/sec, ETA: 0.29 hours
# Processed 8,034,480,656 / 10,000,000,000 tokens so far, 1,904,238 tok/sec, ETA: 0.29 hours
# Processed 8,069,135,076 / 10,000,000,000 tokens so far, 1,905,676 tok/sec, ETA: 0.28 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000080.npy with shape (100000000,) and dtype uint16
# Processed 8,100,002,415 / 10,000,000,000 tokens so far, 1,902,651 tok/sec, ETA: 0.28 hours
# Processed 8,134,171,243 / 10,000,000,000 tokens so far, 1,903,969 tok/sec, ETA: 0.27 hours
# Processed 8,168,473,838 / 10,000,000,000 tokens so far, 1,905,308 tok/sec, ETA: 0.27 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000081.npy with shape (100000000,) and dtype uint16
# Processed 8,200,002,395 / 10,000,000,000 tokens so far, 1,902,228 tok/sec, ETA: 0.26 hours
# Processed 8,234,921,543 / 10,000,000,000 tokens so far, 1,903,703 tok/sec, ETA: 0.26 hours
# Processed 8,269,477,418 / 10,000,000,000 tokens so far, 1,905,085 tok/sec, ETA: 0.25 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000082.npy with shape (100000000,) and dtype uint16
# Processed 8,300,001,381 / 10,000,000,000 tokens so far, 1,901,652 tok/sec, ETA: 0.25 hours
# Processed 8,332,497,095 / 10,000,000,000 tokens so far, 1,902,558 tok/sec, ETA: 0.24 hours
# Processed 8,365,582,469 / 10,000,000,000 tokens so far, 1,903,593 tok/sec, ETA: 0.24 hours
# Processed 8,396,252,185 / 10,000,000,000 tokens so far, 1,904,072 tok/sec, ETA: 0.23 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000083.npy with shape (100000000,) and dtype uint16
# Processed 8,408,600,616 / 10,000,000,000 tokens so far, 1,900,407 tok/sec, ETA: 0.23 hours
# Processed 8,441,880,971 / 10,000,000,000 tokens so far, 1,901,483 tok/sec, ETA: 0.23 hours
# Processed 8,472,568,285 / 10,000,000,000 tokens so far, 1,901,969 tok/sec, ETA: 0.22 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000084.npy with shape (100000000,) and dtype uint16
# Processed 8,500,001,479 / 10,000,000,000 tokens so far, 1,898,445 tok/sec, ETA: 0.22 hours
# Processed 8,534,879,034 / 10,000,000,000 tokens so far, 1,899,869 tok/sec, ETA: 0.21 hours
# Processed 8,567,748,715 / 10,000,000,000 tokens so far, 1,900,839 tok/sec, ETA: 0.21 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000085.npy with shape (100000000,) and dtype uint16
# Processed 8,600,001,374 / 10,000,000,000 tokens so far, 1,897,921 tok/sec, ETA: 0.20 hours
# Processed 8,632,122,245 / 10,000,000,000 tokens so far, 1,898,723 tok/sec, ETA: 0.20 hours
# Processed 8,665,253,060 / 10,000,000,000 tokens so far, 1,899,742 tok/sec, ETA: 0.20 hours
# Processed 8,699,261,889 / 10,000,000,000 tokens so far, 1,900,947 tok/sec, ETA: 0.19 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000086.npy with shape (100000000,) and dtype uint16
# Processed 8,706,447,627 / 10,000,000,000 tokens so far, 1,896,301 tok/sec, ETA: 0.19 hours
# Processed 8,739,764,826 / 10,000,000,000 tokens so far, 1,897,359 tok/sec, ETA: 0.18 hours
# Processed 8,774,401,035 / 10,000,000,000 tokens so far, 1,898,695 tok/sec, ETA: 0.18 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000087.npy with shape (100000000,) and dtype uint16
# Processed 8,800,003,704 / 10,000,000,000 tokens so far, 1,894,530 tok/sec, ETA: 0.18 hours
# Processed 8,831,578,117 / 10,000,000,000 tokens so far, 1,895,207 tok/sec, ETA: 0.17 hours
# Processed 8,863,258,570 / 10,000,000,000 tokens so far, 1,895,903 tok/sec, ETA: 0.17 hours
# Processed 8,897,083,788 / 10,000,000,000 tokens so far, 1,897,051 tok/sec, ETA: 0.16 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000088.npy with shape (100000000,) and dtype uint16
# Processed 8,905,474,967 / 10,000,000,000 tokens so far, 1,892,786 tok/sec, ETA: 0.16 hours
# Processed 8,940,166,510 / 10,000,000,000 tokens so far, 1,894,121 tok/sec, ETA: 0.16 hours
# Processed 8,974,735,839 / 10,000,000,000 tokens so far, 1,895,421 tok/sec, ETA: 0.15 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000089.npy with shape (100000000,) and dtype uint16
# Processed 9,000,003,440 / 10,000,000,000 tokens so far, 1,892,197 tok/sec, ETA: 0.15 hours
# Processed 9,032,550,675 / 10,000,000,000 tokens so far, 1,893,070 tok/sec, ETA: 0.14 hours
# Processed 9,066,683,599 / 10,000,000,000 tokens so far, 1,894,269 tok/sec, ETA: 0.14 hours
# Processed 9,098,665,629 / 10,000,000,000 tokens so far, 1,895,012 tok/sec, ETA: 0.13 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000090.npy with shape (100000000,) and dtype uint16
# Processed 9,113,242,126 / 10,000,000,000 tokens so far, 1,892,136 tok/sec, ETA: 0.13 hours
# Processed 9,147,065,539 / 10,000,000,000 tokens so far, 1,893,263 tok/sec, ETA: 0.13 hours
# Processed 9,181,020,703 / 10,000,000,000 tokens so far, 1,894,409 tok/sec, ETA: 0.12 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000091.npy with shape (100000000,) and dtype uint16
# Processed 9,200,001,735 / 10,000,000,000 tokens so far, 1,891,220 tok/sec, ETA: 0.12 hours
# Processed 9,233,083,135 / 10,000,000,000 tokens so far, 1,892,186 tok/sec, ETA: 0.11 hours
# Processed 9,264,901,749 / 10,000,000,000 tokens so far, 1,892,888 tok/sec, ETA: 0.11 hours
# Processed 9,299,130,733 / 10,000,000,000 tokens so far, 1,894,076 tok/sec, ETA: 0.10 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000092.npy with shape (100000000,) and dtype uint16
# Processed 9,309,274,726 / 10,000,000,000 tokens so far, 1,890,367 tok/sec, ETA: 0.10 hours
# Processed 9,344,013,912 / 10,000,000,000 tokens so far, 1,891,659 tok/sec, ETA: 0.10 hours
# Processed 9,378,817,860 / 10,000,000,000 tokens so far, 1,892,957 tok/sec, ETA: 0.09 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000093.npy with shape (100000000,) and dtype uint16
# Processed 9,400,001,642 / 10,000,000,000 tokens so far, 1,891,114 tok/sec, ETA: 0.09 hours
# Processed 9,434,983,693 / 10,000,000,000 tokens so far, 1,892,440 tok/sec, ETA: 0.08 hours
# Processed 9,469,324,601 / 10,000,000,000 tokens so far, 1,893,630 tok/sec, ETA: 0.08 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000094.npy with shape (100000000,) and dtype uint16
# Processed 9,500,001,178 / 10,000,000,000 tokens so far, 1,891,086 tok/sec, ETA: 0.07 hours
# Processed 9,534,954,726 / 10,000,000,000 tokens so far, 1,892,393 tok/sec, ETA: 0.07 hours
# Processed 9,569,774,494 / 10,000,000,000 tokens so far, 1,893,666 tok/sec, ETA: 0.06 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000095.npy with shape (100000000,) and dtype uint16
# Processed 9,600,056,081 / 10,000,000,000 tokens so far, 1,890,982 tok/sec, ETA: 0.06 hours
# Processed 9,635,269,152 / 10,000,000,000 tokens so far, 1,892,327 tok/sec, ETA: 0.05 hours
# Processed 9,670,040,570 / 10,000,000,000 tokens so far, 1,893,577 tok/sec, ETA: 0.05 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000096.npy with shape (100000000,) and dtype uint16
# Processed 9,700,000,312 / 10,000,000,000 tokens so far, 1,891,186 tok/sec, ETA: 0.04 hours
# Processed 9,734,811,536 / 10,000,000,000 tokens so far, 1,892,438 tok/sec, ETA: 0.04 hours
# Processed 9,769,443,962 / 10,000,000,000 tokens so far, 1,893,649 tok/sec, ETA: 0.03 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000097.npy with shape (100000000,) and dtype uint16
# Processed 9,800,001,011 / 10,000,000,000 tokens so far, 1,891,216 tok/sec, ETA: 0.03 hours
# Processed 9,835,101,842 / 10,000,000,000 tokens so far, 1,892,512 tok/sec, ETA: 0.02 hours
# Processed 9,869,801,965 / 10,000,000,000 tokens so far, 1,893,723 tok/sec, ETA: 0.02 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000098.npy with shape (100000000,) and dtype uint16
# Processed 9,900,002,826 / 10,000,000,000 tokens so far, 1,890,784 tok/sec, ETA: 0.01 hours
# Processed 9,935,536,094 / 10,000,000,000 tokens so far, 1,892,148 tok/sec, ETA: 0.01 hours
# Saved ../data/fineweb-edu-sample-10BT/edufineweb_train_000099.npy with shape (53989344,) and dtype uint16
